# %%
import pymysql

# %%
mydb = pymysql.connect(
    host = 'localhost',
    user = 'root', 
    password = 'oluwaSogo_05',
    database = 'schoolrecordmanagementsystem')
mycursor = mydb.cursor()

# %%
mycursor.execute('select * from studentper where age >= 13 and JS11st >= 80')
for x in mycursor:
    print(x)
# Out:
# ('F', 13, 'URBAN', 'GT3', 'T', 3, 3, 'ADMIN', 'TEACHER', 'father', 1, 3, 'yes', 3, 'no', 2, 'yes', 'no', 'no', 92, 95, 92, 95, 96, 90, 83, 87)
# ('M', 13, 'RURAL', 'GT3', 'T', 3, 3, 'ADMIN', 'NURSE', 'mother', 2, 3, 'no', 5, 'no', 1, 'yes', 'no', 'yes', 98, 88, 85, 82, 86, 82, 84, 81)
# ('F', 13, 'URBAN', 'GT3', 'A', 2, 2, 'BUSINESS', 'HEALTH', 'mother', 2, 3, 'no', 4, 'yes', 2, 'yes', 'yes', 'no', 80, 77, 74, 72, 71, 68, 67, 70)
# ('F', 13, 'RURAL', 'GT3', 'A', 2, 0, 'BUSINESS', 'OTHER', 'mother', 1, 2, 'no', 4, 'yes', 1, 'no', 'no', 'yes', 80, 69, 70, 78, 76, 75, 70, 77)
# ('F', 13, 'RURAL', 'GT3', 'A', 2, 1, 'ADMIN', 'OTHER', 'mother', 2, 1, 'yes', 5, 'yes', 2, 'yes', 'no', 'yes', 80, 79, 84, 84, 83, 74, 83, 82)
# ('F', 13, 'RURAL', 'GT3', 'A', 2, 1, 'OTHER', 'ADMIN', 'mother', 1, 2, 'no', 4, 'yes', 2, 'yes', 'no', 'yes', 90, 92, 89, 87, 84, 88, 90, 91)
# ...

# %%
mycursor.execute('select * from studentper where age >= 13 or JS11st >= 80')
for x in mycursor:
    print(x)
# Out:
# ('M', 13, 'RURAL', 'GT3', 'T', 1, 0, 'OTHER', 'OTHER', 'mother', 3, 2, 'no', 4, 'no', 1, 'yes', 'yes', 'no', 68, 69, 70, 71, 72, 69, 72, 70)
# ('F', 13, 'URBAN', 'LE3', 'A', 3, 2, 'TEACHER', 'HEALTH', 'mother', 2, 3, 'yes', 2, 'no', 1, 'yes', 'yes', 'yes', 60, 61, 66, 65, 67, 61, 69, 70)
# ('F', 13, 'URBAN', 'GT3', 'T', 3, 3, 'ADMIN', 'TEACHER', 'father', 1, 3, 'yes', 3, 'no', 2, 'yes', 'no', 'no', 92, 95, 92, 95, 96, 90, 83, 87)
# ('M', 14, 'RURAL', 'LE3', 'T', 1, 1, 'ADMIN', 'OTHER', 'mother', 2, 3, 'no', 3, 'no', 1, 'no', 'no', 'yes', 75, 81, 90, 70, 69, 95, 68, 73)
# ('F', 13, 'RURAL', 'GT3', 'T', 2, 2, 'OTHER', 'HEALTH', 'mother', 1, 2, 'no', 3, 'no', 1, 'yes', 'yes', 'no', 71, 73, 70, 79, 69, 80, 74, 73)
# ('M', 14, 'URBAN', 'LE3', 'T', 3, 2, 'POLICE', 'OTHER', 'mother', 2, 2, 'yes', 3, 'no', 2, 'yes', 'no', 'yes', 79, 80, 85, 79, 84, 86, 79, 78)
# ...

# %%
mycursor.execute('select * from studentper where (age >= 13 and JS11st >= 80) or (JS22nd = 50)')
for x in mycursor:
    print(x)
# Out:
# ('F', 13, 'URBAN', 'GT3', 'T', 3, 3, 'ADMIN', 'TEACHER', 'father', 1, 3, 'yes', 3, 'no', 2, 'yes', 'no', 'no', 92, 95, 92, 95, 96, 90, 83, 87)
# ('M', 13, 'RURAL', 'GT3', 'T', 3, 3, 'ADMIN', 'NURSE', 'mother', 2, 3, 'no', 5, 'no', 1, 'yes', 'no', 'yes', 98, 88, 85, 82, 86, 82, 84, 81)
# ('F', 13, 'URBAN', 'GT3', 'A', 2, 2, 'BUSINESS', 'HEALTH', 'mother', 2, 3, 'no', 4, 'yes', 2, 'yes', 'yes', 'no', 80, 77, 74, 72, 71, 68, 67, 70)
# ('F', 13, 'RURAL', 'GT3', 'A', 2, 0, 'BUSINESS', 'OTHER', 'mother', 1, 2, 'no', 4, 'yes', 1, 'no', 'no', 'yes', 80, 69, 70, 78, 76, 75, 70, 77)
# ('F', 12, 'RURAL', 'LE3', 'T', 3, 2, 'TEACHER', 'ADMIN', 'mother', 1, 3, 'no', 5, 'yes', 1, 'no', 'no', 'yes', 56, 55, 57, 54, 50, 55, 52, 57)
# ('F', 13, 'RURAL', 'GT3', 'A', 2, 1, 'ADMIN', 'OTHER', 'mother', 2, 1, 'yes', 5, 'yes', 2, 'yes', 'no', 'yes', 80, 79, 84, 84, 83, 74, 83, 82)
# ...

# %%
mycursor.execute('select * from studentper where Mjob like "T%"')
# Out:
# 28

# %%
mycursor.execute('select * from studentper where Mjob like "T%"')
for x in mycursor:
    print(x)
# Out:
# ('F', 13, 'URBAN', 'LE3', 'A', 3, 2, 'TEACHER', 'HEALTH', 'mother', 2, 3, 'yes', 2, 'no', 1, 'yes', 'yes', 'yes', 60, 61, 66, 65, 67, 61, 69, 70)
# ('M', 12, 'URBAN', 'GT3', 'T', 3, 3, 'TEACHER', 'ADMIN', 'mother', 1, 3, 'yes', 5, 'yes', 1, 'yes', 'no', 'yes', 77, 75, 69, 71, 74, 72, 68, 67)
# ('M', 14, 'RURAL', 'GT3', 'T', 3, 2, 'TEACHER', 'ADMIN', 'father', 1, 3, 'yes', 5, 'no', 1, 'no', 'no', 'yes', 79, 80, 75, 74, 79, 80, 81, 79)
# ('F', 12, 'RURAL', 'LE3', 'T', 3, 2, 'TEACHER', 'ADMIN', 'mother', 1, 3, 'no', 5, 'yes', 1, 'no', 'no', 'yes', 56, 55, 57, 54, 50, 55, 52, 57)
# ('F', 13, 'URBAN', 'GT3', 'T', 3, 3, 'TEACHER', 'ADMIN', 'father', 1, 3, 'no', 5, 'yes', 1, 'yes', 'no', 'yes', 86, 70, 75, 70, 87, 87, 72, 79)
# ('M', 13, 'URBAN', 'GT3', 'A', 3, 2, 'TEACHER', 'HEALTH', 'mother', 1, 1, 'no', 2, 'yes', 2, 'yes', 'no', 'no', 77, 67, 74, 72, 70, 71, 69, 73)
# ...

# %%
mycursor.execute('select * from studentper where Mjob like "%T"')
# Out:
# 15

# %%
mycursor.execute('select * from studentper where Mjob like "%T"')
for x in mycursor:
    print(x)
# Out:
# ('M', 12, 'URBAN', 'GT3', 'T', 3, 3, 'CIVIL SERVANT', 'POLICE', 'mother', 1, 4, 'yes', 3, 'yes', 1, 'yes', 'no', 'yes', 70, 65, 60, 63, 65, 62, 61, 68)
# ('F', 14, 'RURAL', 'GT3', 'T', 1, 0, 'CRAFT', 'TRADER', 'other', 0, 0, 'no', 3, 'no', 2, 'yes', 'no', 'yes', 70, 63, 61, 67, 69, 70, 71, 68)
# ('M', 12, 'URBAN', 'LE3', 'T', 3, 3, 'CIVIL SERVANT', 'POLICE', 'mother', 1, 4, 'yes', 3, 'yes', 1, 'yes', 'yes', 'yes', 70, 72, 69, 80, 72, 72, 70, 71)
# ('M', 12, 'URBAN', 'LE3', 'T', 3, 3, 'CIVIL SERVANT', 'POLICE', 'mother', 1, 4, 'yes', 3, 'no', 1, 'yes', 'no', 'yes', 79, 68, 71, 70, 73, 75, 66, 65)
# ('F', 14, 'RURAL', 'GT3', 'T', 1, 0, 'CRAFT', 'TRADER', 'mother', 0, 0, 'yes', 3, 'yes', 2, 'yes', 'no', 'yes', 53, 51, 59, 61, 67, 63, 60, 57)
# ('F', 14, 'RURAL', 'GT3', 'T', 1, 0, 'CRAFT', 'TRADER', 'mother', 0, 0, 'yes', 3, 'yes', 2, 'yes', 'no', 'yes', 68, 73, 66, 63, 65, 72, 69, 63)
# ...

# %%
mycursor.execute('select * from studentper where Fjob like "___S%"')
# Out:
# 5

# %%
mycursor.execute('select * from studentper where Fjob like "___S%"')
for x in mycursor:
    print(x)
# Out:
# ('M', 13, 'RURAL', 'GT3', 'T', 3, 3, 'ADMIN', 'NURSE', 'mother', 2, 3, 'no', 5, 'no', 1, 'yes', 'no', 'yes', 98, 88, 85, 82, 86, 82, 84, 81)
# ('M', 13, 'RURAL', 'LE3', 'T', 3, 3, 'ADMIN', 'NURSE', 'father', 2, 3, 'no', 5, 'no', 1, 'yes', 'yes', 'no', 59, 63, 58, 60, 62, 67, 69, 66)
# ('M', 13, 'RURAL', 'GT3', 'T', 3, 3, 'ADMIN', 'NURSE', 'father', 2, 3, 'no', 5, 'no', 1, 'yes', 'yes', 'no', 55, 56, 70, 66, 53, 54, 58, 59)
# ('M', 13, 'RURAL', 'LE3', 'T', 3, 3, 'ADMIN', 'NURSE', 'mother', 2, 3, 'no', 5, 'no', 1, 'yes', 'no', 'yes', 72, 77, 91, 82, 91, 67, 87, 70)
# ('F', 13, 'RURAL', 'LE3', 'T', 3, 3, 'ADMIN', 'NURSE', 'mother', 2, 3, 'yes', 5, 'yes', 1, 'yes', 'no', 'yes', 67, 80, 83, 76, 75, 62, 85, 79)

# %%
mycursor.execute('select * from studentper where Mjob like "_______"')
# Out:
# 32

# %%
mycursor.execute('select * from studentper where Mjob like "_______"')
for x in mycursor:
    print(x)
# Out:
# ('F', 12, 'URBAN', 'GT3', 'T', 2, 0, 'at_home', 'OTHER', 'father', 3, 1, 'no', 3, 'no', 2, 'yes', 'no', 'yes', 59, 50, 52, 60, 61, 54, 56, 60)
# ('F', 13, 'URBAN', 'LE3', 'A', 3, 2, 'TEACHER', 'HEALTH', 'mother', 2, 3, 'yes', 2, 'no', 1, 'yes', 'yes', 'yes', 60, 61, 66, 65, 67, 61, 69, 70)
# ('M', 12, 'URBAN', 'GT3', 'T', 3, 3, 'TEACHER', 'ADMIN', 'mother', 1, 3, 'yes', 5, 'yes', 1, 'yes', 'no', 'yes', 77, 75, 69, 71, 74, 72, 68, 67)
# ('M', 14, 'RURAL', 'GT3', 'T', 3, 2, 'TEACHER', 'ADMIN', 'father', 1, 3, 'yes', 5, 'no', 1, 'no', 'no', 'yes', 79, 80, 75, 74, 79, 80, 81, 79)
# ('F', 12, 'RURAL', 'LE3', 'T', 3, 2, 'TEACHER', 'ADMIN', 'mother', 1, 3, 'no', 5, 'yes', 1, 'no', 'no', 'yes', 56, 55, 57, 54, 50, 55, 52, 57)
# ('F', 13, 'URBAN', 'GT3', 'T', 3, 3, 'TEACHER', 'ADMIN', 'father', 1, 3, 'no', 5, 'yes', 1, 'yes', 'no', 'yes', 86, 70, 75, 70, 87, 87, 72, 79)
# ...

# %%
mycursor.execute('select * from studentper where Mjob not like "T%"')
# Out:
# 219

# %%
mycursor.execute('select * from studentper where Mjob not like "T%"')
for x in mycursor:
    print(x)
# Out:
# ('M', 13, 'RURAL', 'GT3', 'T', 1, 0, 'OTHER', 'OTHER', 'mother', 3, 2, 'no', 4, 'no', 1, 'yes', 'yes', 'no', 68, 69, 70, 71, 72, 69, 72, 70)
# ('F', 12, 'URBAN', 'GT3', 'T', 2, 0, 'at_home', 'OTHER', 'father', 3, 1, 'no', 3, 'no', 2, 'yes', 'no', 'yes', 59, 50, 52, 60, 61, 54, 56, 60)
# ('M', 12, 'URBAN', 'GT3', 'T', 3, 3, 'CIVIL SERVANT', 'POLICE', 'mother', 1, 4, 'yes', 3, 'yes', 1, 'yes', 'no', 'yes', 70, 65, 60, 63, 65, 62, 61, 68)
# ('F', 13, 'URBAN', 'GT3', 'T', 3, 3, 'ADMIN', 'TEACHER', 'father', 1, 3, 'yes', 3, 'no', 2, 'yes', 'no', 'no', 92, 95, 92, 95, 96, 90, 83, 87)
# ('F', 11, 'URBAN', 'LE3', 'A', 2, 3, 'HEALTH', 'ADMIN', 'mother', 2, 3, 'yes', 3, 'yes', 2, 'yes', 'no', 'yes', 73, 68, 68, 71, 70, 69, 68, 70)
# ('M', 14, 'RURAL', 'LE3', 'T', 1, 1, 'ADMIN', 'OTHER', 'mother', 2, 3, 'no', 3, 'no', 1, 'no', 'no', 'yes', 75, 81, 90, 70, 69, 95, 68, 73)
# ...

# %%
mycursor.execute('select * from studentper where Mjob <> "ADMIN"')
# Out:
# 168

# %%
mycursor.execute('select * from studentper where Mjob <> "ADMIN"')
for x in mycursor:
    print(x)
# Out:
# ('M', 13, 'RURAL', 'GT3', 'T', 1, 0, 'OTHER', 'OTHER', 'mother', 3, 2, 'no', 4, 'no', 1, 'yes', 'yes', 'no', 68, 69, 70, 71, 72, 69, 72, 70)
# ('F', 12, 'URBAN', 'GT3', 'T', 2, 0, 'at_home', 'OTHER', 'father', 3, 1, 'no', 3, 'no', 2, 'yes', 'no', 'yes', 59, 50, 52, 60, 61, 54, 56, 60)
# ('F', 13, 'URBAN', 'LE3', 'A', 3, 2, 'TEACHER', 'HEALTH', 'mother', 2, 3, 'yes', 2, 'no', 1, 'yes', 'yes', 'yes', 60, 61, 66, 65, 67, 61, 69, 70)
# ('M', 12, 'URBAN', 'GT3', 'T', 3, 3, 'CIVIL SERVANT', 'POLICE', 'mother', 1, 4, 'yes', 3, 'yes', 1, 'yes', 'no', 'yes', 70, 65, 60, 63, 65, 62, 61, 68)
# ('F', 11, 'URBAN', 'LE3', 'A', 2, 3, 'HEALTH', 'ADMIN', 'mother', 2, 3, 'yes', 3, 'yes', 2, 'yes', 'no', 'yes', 73, 68, 68, 71, 70, 69, 68, 70)
# ('F', 13, 'RURAL', 'GT3', 'T', 2, 2, 'OTHER', 'HEALTH', 'mother', 1, 2, 'no', 3, 'no', 1, 'yes', 'yes', 'no', 71, 73, 70, 79, 69, 80, 74, 73)
# ...

# %%
mycursor.execute('select * from studentper where Mjob is not null')
for x in mycursor:
    print(x)
# Out:
# ('M', 13, 'RURAL', 'GT3', 'T', 1, 0, 'OTHER', 'OTHER', 'mother', 3, 2, 'no', 4, 'no', 1, 'yes', 'yes', 'no', 68, 69, 70, 71, 72, 69, 72, 70)
# ('F', 12, 'URBAN', 'GT3', 'T', 2, 0, 'at_home', 'OTHER', 'father', 3, 1, 'no', 3, 'no', 2, 'yes', 'no', 'yes', 59, 50, 52, 60, 61, 54, 56, 60)
# ('F', 13, 'URBAN', 'LE3', 'A', 3, 2, 'TEACHER', 'HEALTH', 'mother', 2, 3, 'yes', 2, 'no', 1, 'yes', 'yes', 'yes', 60, 61, 66, 65, 67, 61, 69, 70)
# ('M', 12, 'URBAN', 'GT3', 'T', 3, 3, 'CIVIL SERVANT', 'POLICE', 'mother', 1, 4, 'yes', 3, 'yes', 1, 'yes', 'no', 'yes', 70, 65, 60, 63, 65, 62, 61, 68)
# ('F', 13, 'URBAN', 'GT3', 'T', 3, 3, 'ADMIN', 'TEACHER', 'father', 1, 3, 'yes', 3, 'no', 2, 'yes', 'no', 'no', 92, 95, 92, 95, 96, 90, 83, 87)
# ('F', 11, 'URBAN', 'LE3', 'A', 2, 3, 'HEALTH', 'ADMIN', 'mother', 2, 3, 'yes', 3, 'yes', 2, 'yes', 'no', 'yes', 73, 68, 68, 71, 70, 69, 68, 70)
# ...

# %%
mycursor.execute('select * from studentper where Mjob is null')
# Out:
# 0

# %%
mycursor.execute('select * from studentper where Mjob is null')
for x in mycursor:
    print(x)

# %%
mycursor.execute('select * from studentper where Emotions in (0,2,4)')
# Out:
# 131

# %%
mycursor.execute('select * from studentper where Emotions in (0,2,4)')
for x in mycursor:
    print(x)
# Out:
# ('F', 12, 'URBAN', 'GT3', 'T', 2, 0, 'at_home', 'OTHER', 'father', 3, 1, 'no', 3, 'no', 2, 'yes', 'no', 'yes', 59, 50, 52, 60, 61, 54, 56, 60)
# ('F', 13, 'URBAN', 'GT3', 'T', 3, 3, 'ADMIN', 'TEACHER', 'father', 1, 3, 'yes', 3, 'no', 2, 'yes', 'no', 'no', 92, 95, 92, 95, 96, 90, 83, 87)
# ('F', 11, 'URBAN', 'LE3', 'A', 2, 3, 'HEALTH', 'ADMIN', 'mother', 2, 3, 'yes', 3, 'yes', 2, 'yes', 'no', 'yes', 73, 68, 68, 71, 70, 69, 68, 70)
# ('M', 14, 'URBAN', 'LE3', 'T', 3, 2, 'POLICE', 'OTHER', 'mother', 2, 2, 'yes', 3, 'no', 2, 'yes', 'no', 'yes', 79, 80, 85, 79, 84, 86, 79, 78)
# ('F', 11, 'URBAN', 'GT3', 'A', 2, 3, 'HEALTH', 'ADMIN', 'mother', 2, 3, 'yes', 3, 'no', 2, 'yes', 'no', 'yes', 80, 78, 76, 69, 68, 69, 65, 69)
# ('M', 10, 'URBAN', 'GT3', 'A', 3, 3, 'ADMIN', 'TEACHER', 'father', 2, 3, 'no', 3, 'yes', 2, 'yes', 'no', 'yes', 70, 69, 68, 66, 62, 61, 68, 69)
# ...

# %%
mycursor.execute('select * from studentper where JS11st between 80 and 85')
# Out:
# 27

# %%
mycursor.execute('select * from studentper where JS11st between 80 and 85')
for x in mycursor:
    print(x)
# Out:
# ('F', 11, 'URBAN', 'GT3', 'A', 2, 3, 'HEALTH', 'ADMIN', 'mother', 2, 3, 'yes', 3, 'no', 2, 'yes', 'no', 'yes', 80, 78, 76, 69, 68, 69, 65, 69)
# ('F', 13, 'URBAN', 'GT3', 'A', 2, 2, 'BUSINESS', 'HEALTH', 'mother', 2, 3, 'no', 4, 'yes', 2, 'yes', 'yes', 'no', 80, 77, 74, 72, 71, 68, 67, 70)
# ('F', 13, 'RURAL', 'GT3', 'A', 2, 0, 'BUSINESS', 'OTHER', 'mother', 1, 2, 'no', 4, 'yes', 1, 'no', 'no', 'yes', 80, 69, 70, 78, 76, 75, 70, 77)
# ('F', 13, 'RURAL', 'GT3', 'A', 2, 1, 'ADMIN', 'OTHER', 'mother', 2, 1, 'yes', 5, 'yes', 2, 'yes', 'no', 'yes', 80, 79, 84, 84, 83, 74, 83, 82)
# ('M', 12, 'RURAL', 'GT3', 'T', 1, 1, 'OTHER', 'ADMIN', 'mother', 2, 0, 'yes', 4, 'no', 2, 'yes', 'no', 'yes', 85, 89, 84, 84, 80, 76, 82, 81)
# ('M', 12, 'RURAL', 'LE3', 'T', 2, 1, 'OTHER', 'ADMIN', 'mother', 2, 3, 'no', 5, 'yes', 1, 'yes', 'no', 'yes', 82, 70, 76, 74, 72, 71, 69, 80)
# ...

# %%
mycursor.execute('select distinct(Emotions) from studentper')
for x in mycursor:
    print(x)
# Out:
# (1,)
# (2,)
# (3,)

# %%
mycursor.execute('select * from studentper')
for x in mycursor:
    print(x)
# Out:
# ('M', 13, 'RURAL', 'GT3', 'T', 1, 0, 'OTHER', 'OTHER', 'mother', 3, 2, 'no', 4, 'no', 1, 'yes', 'yes', 'no', 68, 69, 70, 71, 72, 69, 72, 70)
# ('F', 12, 'URBAN', 'GT3', 'T', 2, 0, 'at_home', 'OTHER', 'father', 3, 1, 'no', 3, 'no', 2, 'yes', 'no', 'yes', 59, 50, 52, 60, 61, 54, 56, 60)
# ('F', 13, 'URBAN', 'LE3', 'A', 3, 2, 'TEACHER', 'HEALTH', 'mother', 2, 3, 'yes', 2, 'no', 1, 'yes', 'yes', 'yes', 60, 61, 66, 65, 67, 61, 69, 70)
# ('M', 12, 'URBAN', 'GT3', 'T', 3, 3, 'CIVIL SERVANT', 'POLICE', 'mother', 1, 4, 'yes', 3, 'yes', 1, 'yes', 'no', 'yes', 70, 65, 60, 63, 65, 62, 61, 68)
# ('F', 13, 'URBAN', 'GT3', 'T', 3, 3, 'ADMIN', 'TEACHER', 'father', 1, 3, 'yes', 3, 'no', 2, 'yes', 'no', 'no', 92, 95, 92, 95, 96, 90, 83, 87)
# ('F', 11, 'URBAN', 'LE3', 'A', 2, 3, 'HEALTH', 'ADMIN', 'mother', 2, 3, 'yes', 3, 'yes', 2, 'yes', 'no', 'yes', 73, 68, 68, 71, 70, 69, 68, 70)
# ...

# %%
# mycursor.execute('create table Emotion1 select * from studentper where Emotions = 1')
mycursor.execute('alter table Emotion1 add column EM1ID int not null primary key auto_increment first')
mycursor.execute('show columns from Emotion1')
for x in mycursor:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [33], in <cell line: 2>()
#       1 # mycursor.execute('create table Emotion1 select * from studentper where Emotions = 1')
# ----> 2 mycursor.execute('alter table Emotion1 add column EM1ID int not null primary key auto_increment first')
#       3 mycursor.execute('show columns from Emotion1')
#       4 for x in mycursor:
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# ...

# %%
# mycursor.execute('create table Emotion2 select * from studentper where Emotions = 2')
mycursor.execute('alter table Emotion2 add column EM2ID int not null primary key auto_increment first')
mycursor.execute('show columns from Emotion2')
for x in mycursor:
    print(x)
# Out:
# ('EM2ID', 'int', 'NO', 'PRI', None, 'auto_increment')
# ('sex', 'text', 'YES', '', None, '')
# ('age', 'int', 'YES', '', None, '')
# ('address', 'text', 'YES', '', None, '')
# ('famsize', 'text', 'YES', '', None, '')
# ('Pstatus', 'text', 'YES', '', None, '')
# ('Medu', 'int', 'YES', '', None, '')
# ('Fedu', 'int', 'YES', '', None, '')
# ('Mjob', 'text', 'YES', '', None, '')
# ('Fjob', 'text', 'YES', '', None, '')
# ('guardian', 'text', 'YES', '', None, '')
# ('traveltime', 'int', 'YES', '', None, '')
# ('studytime', 'int', 'YES', '', None, '')
# ('paid', 'text', 'YES', '', None, '')
# ('health', 'int', 'YES', '', None, '')
# ('activities', 'text', 'YES', '', None, '')
# ('Emotions', 'int', 'YES', '', None, '')
# ('famsup', 'text', 'YES', '', None, '')
# ('schoolsup', 'text', 'YES', '', None, '')
# ('internet', 'text', 'YES', '', None, '')
# ('JS11st', 'int', 'YES', '', None, '')
# ('JS12nd', 'int', 'YES', '', None, '')
# ('JS13rd', 'int', 'YES', '', None, '')
# ...

# %%
mycursor.execute('create table Emotion3 select * from studentper where Emotions = 3')
mycursor.execute('alter table Emotion3 add column EM3ID int not null primary key auto_increment first')
mycursor.execute('show columns from Emotion3')
for x in mycursor:
    print(x)
# Out:
# ('EM3ID', 'int', 'NO', 'PRI', None, 'auto_increment')
# ('sex', 'text', 'YES', '', None, '')
# ('age', 'int', 'YES', '', None, '')
# ('address', 'text', 'YES', '', None, '')
# ('famsize', 'text', 'YES', '', None, '')
# ('Pstatus', 'text', 'YES', '', None, '')
# ('Medu', 'int', 'YES', '', None, '')
# ('Fedu', 'int', 'YES', '', None, '')
# ('Mjob', 'text', 'YES', '', None, '')
# ('Fjob', 'text', 'YES', '', None, '')
# ('guardian', 'text', 'YES', '', None, '')
# ('traveltime', 'int', 'YES', '', None, '')
# ('studytime', 'int', 'YES', '', None, '')
# ('paid', 'text', 'YES', '', None, '')
# ('health', 'int', 'YES', '', None, '')
# ('activities', 'text', 'YES', '', None, '')
# ('Emotions', 'int', 'YES', '', None, '')
# ('famsup', 'text', 'YES', '', None, '')
# ('schoolsup', 'text', 'YES', '', None, '')
# ('internet', 'text', 'YES', '', None, '')
# ('JS11st', 'int', 'YES', '', None, '')
# ('JS12nd', 'int', 'YES', '', None, '')
# ('JS13rd', 'int', 'YES', '', None, '')
# ...

# %%
mycursor.execute('show tables')
for x in mycursor:
    print(x)
# Out:
# ('emotion1',)
# ('emotion2',)
# ('emotion3',)
# ('studentper',)

# %%
mycursor.execute('select emotion1.JS11st, emotion1.JS12nd, emotion2.JS21st, emotion2.JS22nd from emotion1 inner join emotion2 on emotion1.EM1ID = emotion2.EM2ID')
for x in mycursor:
    print(x)
# Out:
# (71, 72, 60, 61)
# (64, 63, 95, 96)
# (72, 70, 71, 70)
# (60, 61, 79, 84)
# (68, 69, 66, 61)
# (60, 61, 69, 68)
# (70, 65, 91, 88)
# (75, 81, 66, 62)
# (69, 55, 94, 89)
# (66, 67, 75, 71)
# (87, 86, 61, 59)
# (83, 85, 67, 69)
# (72, 77, 72, 71)
# (80, 78, 51, 60)
# (80, 81, 49, 48)
# (84, 82, 53, 51)
# (69, 78, 60, 86)
# (77, 80, 63, 65)
# (70, 82, 70, 75)
# (75, 78, 74, 81)
# (71, 73, 80, 78)
# (75, 79, 64, 60)
# (66, 80, 68, 73)
# (68, 84, 70, 69)
# (56, 67, 65, 69)
# (73, 77, 59, 67)
# (98, 88, 84, 83)
# (77, 75, 62, 59)
# (60, 78, 70, 71)
# (80, 69, 84, 80)
# (67, 78, 69, 70)
# (69, 75, 80, 79)
# (66, 67, 69, 60)
# (66, 70, 71, 73)
# (79, 80, 54, 52)
# (80, 75, 61, 59)
# (56, 55, 60, 72)
# (67, 80, 80, 78)
# (63, 84, 70, 61)
# (60, 58, 87, 84)
# (70, 71, 65, 62)
# (60, 58, 60, 72)
# (68, 69, 50, 54)
# (77, 75, 68, 73)
# (59, 50, 85, 84)
# (82, 70, 68, 69)
# (60, 61, 82, 89)
# (86, 82, 61, 64)
# (92, 95, 71, 65)
# (86, 70, 84, 88)
# (73, 68, 70, 68)
# (70, 72, 57, 60)
# ...

# %%
mycursor.execute('select emotion1.JS11st, emotion1.JS12nd, emotion2.JS21st, emotion2.JS22nd from emotion1 left join emotion2 on emotion1.EM1ID = emotion2.EM2ID')
for x in mycursor:
    print(x)
# Out:
# (71, 72, 60, 61)
# (64, 63, 95, 96)
# (72, 70, 71, 70)
# (60, 61, 79, 84)
# (68, 69, 66, 61)
# (60, 61, 69, 68)
# (70, 65, 91, 88)
# (75, 81, 66, 62)
# (69, 55, 94, 89)
# (66, 67, 75, 71)
# (87, 86, 61, 59)
# (83, 85, 67, 69)
# (72, 77, 72, 71)
# (80, 78, 51, 60)
# (80, 81, 49, 48)
# (84, 82, 53, 51)
# (69, 78, 60, 86)
# (77, 80, 63, 65)
# (70, 82, 70, 75)
# (75, 78, 74, 81)
# (71, 73, 80, 78)
# (75, 79, 64, 60)
# (66, 80, 68, 73)
# (68, 84, 70, 69)
# (56, 67, 65, 69)
# (73, 77, 59, 67)
# (98, 88, 84, 83)
# (77, 75, 62, 59)
# (60, 78, 70, 71)
# (80, 69, 84, 80)
# (67, 78, 69, 70)
# (69, 75, 80, 79)
# (66, 67, 69, 60)
# (66, 70, 71, 73)
# (79, 80, 54, 52)
# (80, 75, 61, 59)
# (56, 55, 60, 72)
# (67, 80, 80, 78)
# (63, 84, 70, 61)
# (60, 58, 87, 84)
# (70, 71, 65, 62)
# (60, 58, 60, 72)
# (68, 69, 50, 54)
# (77, 75, 68, 73)
# (59, 50, 85, 84)
# (82, 70, 68, 69)
# (60, 61, 82, 89)
# (86, 82, 61, 64)
# (92, 95, 71, 65)
# (86, 70, 84, 88)
# (73, 68, 70, 68)
# (70, 72, 57, 60)
# ...

# %%
mycursor.execute('select emotion1.JS11st, emotion1.JS12nd, emotion2.JS21st, emotion2.JS22nd from emotion1 right join emotion2 on emotion1.EM1ID = emotion2.EM2ID')
for x in mycursor:
    print(x)
# Out:
# (71, 72, 60, 61)
# (64, 63, 95, 96)
# (72, 70, 71, 70)
# (60, 61, 79, 84)
# (68, 69, 66, 61)
# (60, 61, 69, 68)
# (70, 65, 91, 88)
# (75, 81, 66, 62)
# (69, 55, 94, 89)
# (66, 67, 75, 71)
# (87, 86, 61, 59)
# (83, 85, 67, 69)
# (72, 77, 72, 71)
# (80, 78, 51, 60)
# (80, 81, 49, 48)
# (84, 82, 53, 51)
# (69, 78, 60, 86)
# (77, 80, 63, 65)
# (70, 82, 70, 75)
# (75, 78, 74, 81)
# (71, 73, 80, 78)
# (75, 79, 64, 60)
# (66, 80, 68, 73)
# (68, 84, 70, 69)
# (56, 67, 65, 69)
# (73, 77, 59, 67)
# (98, 88, 84, 83)
# (77, 75, 62, 59)
# (60, 78, 70, 71)
# (80, 69, 84, 80)
# (67, 78, 69, 70)
# (69, 75, 80, 79)
# (66, 67, 69, 60)
# (66, 70, 71, 73)
# (79, 80, 54, 52)
# (80, 75, 61, 59)
# (56, 55, 60, 72)
# (67, 80, 80, 78)
# (63, 84, 70, 61)
# (60, 58, 87, 84)
# (70, 71, 65, 62)
# (60, 58, 60, 72)
# (68, 69, 50, 54)
# (77, 75, 68, 73)
# (59, 50, 85, 84)
# (82, 70, 68, 69)
# (60, 61, 82, 89)
# (86, 82, 61, 64)
# (92, 95, 71, 65)
# (86, 70, 84, 88)
# (73, 68, 70, 68)
# (70, 72, 57, 60)
# ...

# %%
mycursor.execute('select emotion1.JS11st, emotion1.JS12nd, emotion2.JS21st, emotion2.JS22nd from emotion1 cross join emotion2 on emotion1.EM1ID = emotion2.EM2ID')
for x in mycursor:
    print(x)
# Out:
# (71, 72, 60, 61)
# (64, 63, 95, 96)
# (72, 70, 71, 70)
# (60, 61, 79, 84)
# (68, 69, 66, 61)
# (60, 61, 69, 68)
# (70, 65, 91, 88)
# (75, 81, 66, 62)
# (69, 55, 94, 89)
# (66, 67, 75, 71)
# (87, 86, 61, 59)
# (83, 85, 67, 69)
# (72, 77, 72, 71)
# (80, 78, 51, 60)
# (80, 81, 49, 48)
# (84, 82, 53, 51)
# (69, 78, 60, 86)
# (77, 80, 63, 65)
# (70, 82, 70, 75)
# (75, 78, 74, 81)
# (71, 73, 80, 78)
# (75, 79, 64, 60)
# (66, 80, 68, 73)
# (68, 84, 70, 69)
# (56, 67, 65, 69)
# (73, 77, 59, 67)
# (98, 88, 84, 83)
# (77, 75, 62, 59)
# (60, 78, 70, 71)
# (80, 69, 84, 80)
# (67, 78, 69, 70)
# (69, 75, 80, 79)
# (66, 67, 69, 60)
# (66, 70, 71, 73)
# (79, 80, 54, 52)
# (80, 75, 61, 59)
# (56, 55, 60, 72)
# (67, 80, 80, 78)
# (63, 84, 70, 61)
# (60, 58, 87, 84)
# (70, 71, 65, 62)
# (60, 58, 60, 72)
# (68, 69, 50, 54)
# (77, 75, 68, 73)
# (59, 50, 85, 84)
# (82, 70, 68, 69)
# (60, 61, 82, 89)
# (86, 82, 61, 64)
# (92, 95, 71, 65)
# (86, 70, 84, 88)
# (73, 68, 70, 68)
# (70, 72, 57, 60)
# ...

# %%
# Out:
# Running cells with 'Python 3.9.13 ('assignment 10': venv)' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/USER/Documents/Learning Python/assignment 10/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
